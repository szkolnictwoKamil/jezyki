# %%
import pandas as pd

df1 = pd.read_csv("C:/repo/Plant_1_Generation_Data.csv", sep = ',', parse_dates=['DATE_TIME'], index_col = 0)

df2 = pd.read_csv("C:/repo/Plant_2_Generation_Data.csv", sep = ',', parse_dates=['DATE_TIME'], index_col = 0)

df = pd.concat([df1, df2], axis=0)
df.dropna()
# Out:
#                       PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# DATE_TIME
# 2020-05-15 00:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:00:00  4135001.0  1IF53ai7Xc0U56Y       0.0       0.0
# 2020-05-15 00:00:00  4135001.0  3PZuoBAID5Wc2HD       0.0       0.0
# 2020-05-15 00:00:00  4135001.0  7JYdWkrLSPkdwr4       0.0       0.0
# 2020-05-15 00:00:00  4135001.0  McdE0feGgRqW7Ca       0.0       0.0
# ...                        ...              ...       ...       ...
# 2020-06-17 23:45:00  4136001.0  q49J1IKaHRwDQnt       0.0       0.0
# 2020-06-17 23:45:00  4136001.0  rrq4fwE8jgrTyWY       0.0       0.0
# 2020-06-17 23:45:00  4136001.0  vOuJvMaM2sgwLmb       0.0       0.0
# 2020-06-17 23:45:00  4136001.0  xMbIugepa2P7lBB       0.0       0.0
# 2020-06-17 23:45:00  4136001.0  xoJJ8DcxJEcupym       0.0       0.0
#
#                      DAILY_YIELD  TOTAL_YIELD
# DATE_TIME
# 2020-05-15 00:00:00          0.0    6259559.0
# ...

# %%
df_specific = df[df['SOURCE_KEY'] == '1BY6WEcLGh8j5v7']
df_specific
# Out:
#                       PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# DATE_TIME
# 2020-05-15 00:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:15:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:30:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 01:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# ...                        ...              ...       ...       ...
# 2020-06-17 22:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-06-17 23:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-06-17 23:15:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-06-17 23:30:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-06-17 23:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
#
#                      DAILY_YIELD  TOTAL_YIELD
# DATE_TIME
# 2020-05-15 00:00:00          0.0    6259559.0
# ...

# %%
df_week = df_specific.loc['2020-05-14':'2020-05-21']
df_week

df.loc[:, "AVG"] = df.groupby(df.index)['AC_POWER'].mean()
df_avg = df.loc['2020-05-15':'2020-05-21']
# Out:
#                       PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# DATE_TIME
# 2020-05-15 00:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:15:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:30:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 00:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-15 01:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# ...                        ...              ...       ...       ...
# 2020-05-21 22:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-21 23:00:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-21 23:15:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-21 23:30:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
# 2020-05-21 23:45:00  4135001.0  1BY6WEcLGh8j5v7       0.0       0.0
#
#                      DAILY_YIELD  TOTAL_YIELD
# DATE_TIME
# 2020-05-15 00:00:00          0.0    6259559.0
# ...

# %%
df_week.AC_POWER.plot()

df_avg.AVG.plot(color = 'r', xlabel = 'Day', ylabel = 'AC_POWER', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Day', ylabel='AC_POWER'>

# %%
df_below_avg = df[df["AC_POWER"] < 0.8*df["AVG"]]
df_below_avg
# Out:
#                       PLANT_ID       SOURCE_KEY    DC_POWER    AC_POWER  \
# DATE_TIME
# 2020-05-15 06:00:00  4135001.0  1BY6WEcLGh8j5v7   37.142857    3.585714
# 2020-05-15 06:00:00  4135001.0  1IF53ai7Xc0U56Y   53.500000    5.162500
# 2020-05-15 06:00:00  4135001.0  3PZuoBAID5Wc2HD   58.000000    5.585714
# 2020-05-15 06:00:00  4135001.0  7JYdWkrLSPkdwr4   58.428571    5.628571
# 2020-05-15 06:00:00  4135001.0  McdE0feGgRqW7Ca   54.375000    5.250000
# ...                        ...              ...         ...         ...
# 2020-06-17 17:00:00  4136001.0  vOuJvMaM2sgwLmb   53.300000   51.633333
# 2020-06-17 17:00:00  4136001.0  xMbIugepa2P7lBB   57.033333   55.266667
# 2020-06-17 17:00:00  4136001.0  xoJJ8DcxJEcupym   51.193333   49.573333
# 2020-06-17 17:15:00  4136001.0  Quc1TzYxW2pYoWX  105.866667  102.900000
# 2020-06-17 18:15:00  4136001.0  Quc1TzYxW2pYoWX   25.726667   24.846667
#
#                      DAILY_YIELD   TOTAL_YIELD         AVG
# DATE_TIME
# ...

# %%
df_below_avg.SOURCE_KEY.value_counts()
# Out:
# Quc1TzYxW2pYoWX    682
# Et9kgGMDl729KT4    517
# LYwnQax7tkwH5Cb    495
# rrq4fwE8jgrTyWY    468
# WcxssY2VbP4hApt    425
# q49J1IKaHRwDQnt    409
# 81aHJ1q11NBPMrL    401
# xoJJ8DcxJEcupym    345
# LlT2YUhhzqhg5Sw    341
# PeE6FRyGXUgsRhN    332
# 9kRcWv60rDACzjR    330
# oZZkBaNadn6DNKz    310
# V94E5Ben1TlhnDV    294
# bvBOhCH3iADSZry    294
# vOuJvMaM2sgwLmb    279
# 1BY6WEcLGh8j5v7    278
# oZ35aAeoifZaQzV    256
# Qf4GUc1pJu5T6c6    251
# 4UPUqMRk7TRMgml    244
# Mx2yZCDsyf6DPfv    218
# ih0vzX44oOqAx2f    200
# z9Y9gH1T5YWrNuG    199
# zVJPv84UY57bAof    192
# rGa61gmuvPhdLxV    192
# wCURE6d3bPkepu2    190
# pkci93gMrogZuBj    190
# sjndEbLyjtCKgGv    190
# WRmjgnKYAwPKWDb    188
# zBIq5rxdHJRwDNY    187
# ZoEaEvLYb1n2sOq    185
# iCRJl6heRkivqQ3    184
# YxYtjZvoooNbGkE    184
# 7JYdWkrLSPkdwr4    183
# uHbuxQJl8lW7ozc    180
# ZnxXDlPa8U1GXgE    179
# McdE0feGgRqW7Ca    174
# 3PZuoBAID5Wc2HD    174
# VHMLBKoKgIrUVDU    167
# 1IF53ai7Xc0U56Y    165
# adLQvlD726eNBSB    155
# ...
